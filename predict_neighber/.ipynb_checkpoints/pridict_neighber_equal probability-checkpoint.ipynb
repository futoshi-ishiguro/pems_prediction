# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation
from tensorflow.keras.layers import LSTM
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.ensemble import RandomForestRegressor
from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import IterativeImputer
from IPython.display import clear_output
import itertools
import time
import os

# %%
"""
imputation_select = {"rf","mean","mice"}
missing_rate
"""

imputation_select = "rf"
missing_rate = 0.2

# %%
#csvのパスを設定
#csv_path = "/Users/ishigurofutoshi/lab_materials/data/integrated_route.csv"
csv_path = "C:/Users/meida/lab_materials/pems/missing_data/pems_prediction/data/data/integrated_route.csv"

#output_path = "/Users/ishigurofutoshi/lab_materials/test/"+imputation_select
output_path = "C:/Users/meida/lab_materials/pems/missing_data/pems_prediction/output/equal_probability/neighbor/"+imputation_select

fig_output_path = output_path+"/fig/"+str(missing_rate)
excel_output_path = output_path+"/excel"

# %%
df = pd.read_csv(csv_path,index_col=0)
# Slice [start:stop:step], starting from index 5 take every 6th record.
#df = df[5::6]
df = df.dropna(axis=1)
date_time = pd.to_datetime(df.pop('5 Minutes'), format='%Y.%m.%d %H:%M').reset_index(drop=True)

# %%
#n_input = 10
n_min_ahead = 6
window_len = 24

plot_start = 900
plot_range = 100

# %%
df = df.reset_index(drop=True)

# %% [markdown]
# ### 標準化

# %%
column_indices = {name: i for i, name in enumerate(df.columns)}

n = len(df)
#train_df = df[0:int(n*0.9)]
#val_df = df[int(n*0.7):int(n*0.9)]
#test_df = df[int(n*0.9):]

num_features = df.shape[1]

# %%
df_mean = df.mean()
df_std = df.std()

df = (df - df_mean) / df_std
#val_df = (val_df - train_mean) / train_std
#test_df = (test_df - train_mean) / train_std

# %%
def select_index(target):
    #df_neighber = pd.read_excel("/Users/ishigurofutoshi/lab_materials/data/neighber_link_matrix.xlsx",index_col=0)
    df_neighber = pd.read_excel("C:/Users/meida/lab_materials/pems/missing_data/pems_prediction/data/data/neighber_link_matrix.xlsx",index_col=0)
    
    index = []
    for id in df_neighber.index:
        if df_neighber.loc[id,float(target)] == 1:
            index.append(str(id))
    n_input = len(index)
    return index,n_input

# %%
def init_df(target,imputation_select):
    select_features,n_input = select_index(target)

    df_for_target = df.loc[:,select_features]
    
    labels_df_time = pd.concat((date_time,df_for_target.loc[:,target]),axis=1,sort=False)
    inputs_df_time = pd.concat((date_time,df_for_target.loc[:,select_features]),axis=1,sort=False)
    
    for t in range(24):
        for i in labels_df_time.iloc[:int(80100*0.9)].loc[labels_df_time["5 Minutes"].dt.hour==t].sample(frac=missing_rate).index:
            labels_df_time.loc[i,target] = np.nan
        for route in select_features:
            for i in inputs_df_time.loc[inputs_df_time["5 Minutes"].dt.hour==t].sample(frac=missing_rate).index:
                inputs_df_time.loc[i,route] = np.nan
                
    inputs_df = inputs_df_time.drop(["5 Minutes"],axis=1)
    labels_df = labels_df_time.drop(["5 Minutes"],axis=1)

    if imputation_select=="rf":
        #RandomForest imputation
        inputs_df,labels_df = random_forest_imputation(inputs_df,labels_df,select_features)
    elif imputation_select=="mean":
        #mean imputation
        inputs_df,labels_df = mean_imputation(inputs_df,labels_df)
        
    elif imputation_select=="mice":
        #MICE
        inputs_df,labels_df = mice_imputation(inputs_df,labels_df,select_features)
    
    return inputs_df,labels_df,inputs_df_time,labels_df_time,select_features,n_input

# %%
def random_forest_imputation(inputs_df,labels_df,select_features):
    rf = RandomForestRegressor(n_estimators=10, n_jobs=-1)
    imp = IterativeImputer(random_state=0,estimator=rf)
    inputs_df = pd.DataFrame(imp.fit_transform(inputs_df),columns=select_features)
    labels_df = pd.DataFrame(imp.fit_transform(labels_df))
    return inputs_df,labels_df

# %%
def mean_imputation(inputs_df,labels_df):
    inputs_df = inputs_df.fillna(inputs_df.mean())
    labels_df = labels_df.fillna(labels_df.mean())
    return inputs_df,labels_df

# %%
from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import IterativeImputer

def mice_imputation(inputs_df,labels_df,select_features):
    imp = IterativeImputer(max_iter=10, random_state=0, sample_posterior=True,tol=0.0001)
    inputs_df = pd.DataFrame(imp.fit_transform(inputs_df),columns=select_features)
    labels_df = pd.DataFrame(imp.fit_transform(labels_df))
    return inputs_df,labels_df

# %%
def show_imputation(target,inputs_df,select_features):
    original = df[target].values
    imputation = inputs_df[target].values
    
    plt.figure(figsize=(15,10))

    plt.scatter(range(30),original[:30],color="blue")
    plt.scatter(range(30),imputation[:30],color="red")
    
    dirname = fig_output_path+"/imputation/"
    os.makedirs(dirname, exist_ok=True)
    plt.savefig(dirname+target+".png")

    plt.show()

# %%
def make_dataset(labels_df,inputs_df,window_len):
    labels, inputs = [], []
    for i in range(len(labels_df)-(window_len+n_min_ahead-1)):
        labels.append(labels_df.iloc[i+window_len+n_min_ahead-1])
        inputs.append(inputs_df.iloc[i:i+window_len])
    re_labels = np.array(labels).reshape(len(labels),1)
    re_inputs = np.array(inputs).reshape(len(inputs),window_len,n_input)
    
    return re_labels,re_inputs

# %%
def show_prediction(test_y,predicted):
    plt.figure(figsize=(15,10))

    plt.plot(test_y[plot_start:plot_start+plot_range],color="blue")
    plt.plot(predicted[plot_start:plot_start+plot_range],color="orange")
    
    dirname = fig_output_path+"/prediction/"
    os.makedirs(dirname, exist_ok=True)
    plt.savefig(dirname+target+".png")

# %%
def show_missing_position(test_y,labels_df_time,select_features):
    NaN_position = [np.nan for i in range(len(test_y))]
    measured_position = [np.nan for i in range(len(test_y))]
    tmp = list(itertools.chain.from_iterable(test_y))

    for i in range(len(test_y)):
        if np.isnan(labels_df_time.iloc[i,1]):
            NaN_position[i] = tmp[i]
        else:
            measured_position[i] = tmp[i]
    NaN_mask = [[0 for i in range(len(select_features))] for j in range(len(test_x[plot_start:plot_start+plot_range,:]))]

    c_num = 0
    for c in select_features:
        for i in range(len(test_x[plot_start:plot_start+plot_range,:])):
            if np.isnan(inputs_df_time[c].iloc[int(n*0.9)+plot_start+i,]):
                NaN_mask[i][c_num] = 1
        c_num += 1

    NaN_mask = np.array(NaN_mask)
    NaN_mask_df = pd.DataFrame(data=NaN_mask.T,index=select_features,columns=inputs_df_time["5 Minutes"].iloc[int(n*0.9)+plot_start:int(n*0.9)+plot_start+plot_range,].dt.strftime("%Y/%m/%d-%H:%M"))
    
    plt.figure(figsize=(15,10))
    sns.set(rc={"figure.figsize":(15,3)})
    sns.heatmap(NaN_mask_df,cmap="Reds",cbar=False)
    
    dirname = fig_output_path+"/missing_position/"
    os.makedirs(dirname, exist_ok=True)
    plt.savefig(dirname+target+".png")

# %%
def evaluation(evaluation_list,training_time):
    performance = model.evaluate(test_x,test_y, verbose=0)
    evaluation_list.append([performance,training_time])
    
    return evaluation_list

# %%
evaluation_list = []
for target in df.columns:

    index_target = df.columns.get_loc(target)
    
    #DataFrameの作成（欠損作成＆補完）

    inputs_df,labels_df,inputs_df_time,labels_df_time,select_features,n_input = init_df(target,imputation_select)
    
    #単一値補完の描画
    show_imputation(target,inputs_df,select_features)
    
    labels_ds, inputs_ds = make_dataset(labels_df,inputs_df,window_len)
    
    n = len(inputs_ds)
    train_x, test_x = inputs_ds[:int(n*0.9)],inputs_ds[int(n*0.9):] 
    train_y, test_y = labels_ds[:int(n*0.9)],labels_ds[int(n*0.9):]
    
    # モデル構築
    # 1つの学習データのwindowサイズ
    length_of_sequence = inputs_ds.shape[1] 
    in_out_neurons = 1
    n_hidden = 300

    model = Sequential()
    #model.add(LSTM(n_hidden, batch_input_shape=(None, length_of_sequence, n_input), return_sequences=True))
    #model.add(LSTM(n_hidden, batch_input_shape=(None, length_of_sequence, n_input), return_sequences=True))
    model.add(LSTM(n_hidden, batch_input_shape=(None, length_of_sequence, n_input), return_sequences=False))
    model.add(Dense(in_out_neurons))
    #model.add(Activation("linear"))
    optimizer = Adam(learning_rate=0.001)
    model.compile(loss="mean_squared_error", optimizer=optimizer)
    
    early_stopping = EarlyStopping(monitor='val_loss', mode='auto', patience=5)
    
    start = time.time()
    model.fit(train_x, train_y,
          batch_size=300,
          epochs=100,
          validation_split=0.1,
          callbacks=[early_stopping]
          )
    training_time = time.time()-start
    
    #モデルテスト
    predicted = model.predict(test_x)
    
    #予測値と観測値の描画
    show_prediction(test_y,predicted)
    
    #欠損値の描画
    show_missing_position(test_y,labels_df_time,select_features)
    
    #評価結果の出力
    evaluation_list = evaluation(evaluation_list,training_time)
    print(evaluation_list)
# Out:
# /Users/ishigurofutoshi/opt/anaconda3/envs/pems/lib/python3.7/site-packages/sklearn/impute/_iterative.py:701: ConvergenceWarning: [IterativeImputer] Early stopping criterion not reached.
#   ConvergenceWarning,
# 2022-09-08 13:04:45.896151: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Epoch 1/100
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_train_function.<locals>.train_function at 0x7f85571434d0> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_train_function.<locals>.train_function at 0x7f85571434d0> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# 216/217 [============================>.] - ETA: 0s - loss: 0.2135WARNING:tensorflow:AutoGraph could not transform <function Model.make_test_function.<locals>.test_function at 0x7f8557108c20> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_test_function.<locals>.test_function at 0x7f8557108c20> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# 217/217 [==============================] - 39s 170ms/step - loss: 0.2134 - val_loss: 0.3947
# Epoch 2/100
# 217/217 [==============================] - 36s 165ms/step - loss: 0.1963 - val_loss: 0.4013
# Epoch 3/100
# 217/217 [==============================] - 36s 166ms/step - loss: 0.1931 - val_loss: 0.3911
# Epoch 4/100
# 217/217 [==============================] - 36s 167ms/step - loss: 0.1915 - val_loss: 0.3835
# Epoch 5/100
# 217/217 [==============================] - 37s 169ms/step - loss: 0.1905 - val_loss: 0.3895
# Epoch 6/100
# 217/217 [==============================] - 36s 166ms/step - loss: 0.1894 - val_loss: 0.4008
# Epoch 7/100
# 217/217 [==============================] - 36s 167ms/step - loss: 0.1885 - val_loss: 0.3909
# Epoch 8/100
# 217/217 [==============================] - 36s 167ms/step - loss: 0.1869 - val_loss: 0.4165
# Epoch 9/100
# 217/217 [==============================] - 38s 174ms/step - loss: 0.1855 - val_loss: 0.3998
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x7f8544e669e0> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x7f8544e669e0> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# [[0.3774726986885071, 329.5101580619812]]
# /Users/ishigurofutoshi/opt/anaconda3/envs/pems/lib/python3.7/site-packages/sklearn/impute/_iterative.py:701: ConvergenceWarning: [IterativeImputer] Early stopping criterion not reached.
#   ConvergenceWarning,
# Epoch 1/100
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_train_function.<locals>.train_function at 0x7f8664494ef0> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_train_function.<locals>.train_function at 0x7f8664494ef0> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# 216/217 [============================>.] - ETA: 0s - loss: 0.2145WARNING:tensorflow:AutoGraph could not transform <function Model.make_test_function.<locals>.test_function at 0x7f8545176f80> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_test_function.<locals>.test_function at 0x7f8545176f80> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# 217/217 [==============================] - 39s 172ms/step - loss: 0.2146 - val_loss: 0.4480
# Epoch 2/100
# 217/217 [==============================] - 35s 160ms/step - loss: 0.1964 - val_loss: 0.4421
# Epoch 3/100
# 217/217 [==============================] - 35s 160ms/step - loss: 0.1913 - val_loss: 0.4277
# Epoch 4/100
# 217/217 [==============================] - 36s 165ms/step - loss: 0.1872 - val_loss: 0.4235
# Epoch 5/100
# 217/217 [==============================] - 35s 161ms/step - loss: 0.1846 - val_loss: 0.4340
# Epoch 6/100
# 217/217 [==============================] - 34s 159ms/step - loss: 0.1812 - val_loss: 0.4433
# Epoch 7/100
# 217/217 [==============================] - 35s 161ms/step - loss: 0
0> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# [[0.3774726986885071, 329.5101580619812], [0.2576304078102112, 317.5680809020996], [0.10476814210414886, 624.9277789592743], [0.0592956505715847, 335.75038290023804], [0.06946622580289841, 290.8102331161499], [0.19382649660110474, 309.30135583877563], [0.21224841475486755, 318.4884521961212]]
# /Users/ishigurofutoshi/opt/anaconda3/envs/pems/lib/python3.7/site-packages/sklearn/impute/_iterative.py:701: ConvergenceWarning: [IterativeImputer] Early stopping criterion not reached.
#   ConvergenceWarning,
# Epoch 1/100
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_train_function.<locals>.train_function at 0x7f8417aedd40> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_train_function.<locals>.train_function at 0x7f8417aedd40> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# 216/217 [============================>.] - ETA: 0s - loss: 0.2016WARNING:tensorflow:AutoGraph could not transform <function Model.make_test_function.<locals>.test_function at 0x7f8545176a70> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_test_function.<locals>.test_function at 0x7f8545176a70> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# 217/217 [==============================] - 37s 163ms/step - loss: 0.2016 - val_loss: 0.2978
# Epoch 2/100
# 217/217 [==============================] - 35s 161ms/step - loss: 0.1834 - val_loss: 0.3019
# Epoch 3/100
# 217/217 [==============================] - 35s 160ms/step - loss: 0.1805 - val_loss: 0.3012
# Epoch 4/100
# 217/217 [==============================] - 35s 161ms/step - loss: 0.1774 - val_loss: 0.3107
# Epoch 5/100
# 217/217 [==============================] - 35s 162ms/step - loss: 0.1769 - val_loss: 0.2968
# Epoch 6/100
# 217/217 [==============================] - 36s 164ms/step - loss: 0.1752 - val_loss: 0.3032
# Epoch 7/100
# 217/217 [==============================] - 35s 162ms/step - loss: 0.1745 - val_loss: 0.2940
# Epoch 8/100
# 217/217 [==============================] - 35s 161ms/step - loss: 0.1729 - val_loss: 0.2925
# Epoch 9/100
# 217/217 [==============================] - 35s 161ms/step - loss: 0.1728 - val_loss: 0.2893
# Epoch 10/100
# 217/217 [==============================] - 35s 163ms/step - loss: 0.1732 - val_loss: 0.2922
# Epoch 11/100
# 217/217 [==============================] - 35s 163ms/step - loss: 0.1704 - val_loss: 0.2938
# Epoch 12/100
# 217/217 [==============================] - 35s 163ms/step - loss: 0.1700 - val_loss: 0.3000
# Epoch 13/100
# 217/217 [==============================] - 35s 163ms/step - loss: 0.1698 - val_loss: 0.2947
# Epoch 14/100
# 217/217 [==============================] - 35s 162ms/step - loss: 0.1683 - val_loss: 0.2943
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x7f85575cf830> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x7f85575cf830> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# [[0.3774726986885071, 329.5101580619812], [0.2576304078102112, 317.5680809020996], [0.10476814210414886, 624.9277789592743], [0.0592956505715847, 335.75038290023804], [0.06946622580289841, 290.8102331161499], [0.19382649660110474, 309.30135583877563], [0.21224841475486755, 318.4884521961212], [0.09543122351169586, 493.1862289905548]]
# /Users/ishigurofutoshi/opt/anaconda3/envs/pems/lib/python3.7/site-packages/sklearn/impute/_iterative.py:701: ConvergenceWarning: [IterativeImputer] Early stopping criterion not reached.
#   ConvergenceWarning,
# Epoch 1/100
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_train_function.<locals>.train_function at 0x7f854a164710> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_train_function.<locals>.train_function at 0x7f854a164710> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# 216/217 [============================>.] - ETA: 0s - loss: 0.1679WARNING:tensorflow:AutoGraph could not transform <function Model.make_test_function.<locals>.test_function at 0x7f8544e01050> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_test_function.<locals>.test_function at 0x7f8544e01050> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# 217/217 [==============================] - 36s 162ms/step - loss: 0.1678 - val_loss: 0.3292
# Epoch 2/100
# 217/217 [==============================] - 35s 160ms/step - loss: 0.1537 - val_loss: 0.3146
# Epoch 3/100
# 217/217 [==============================] - 35s 160ms/step - loss: 0.1506 - val_loss: 0.3133
# Epoch 4/100
# 217/217 [==============================] - 35s 160ms/step - loss: 0.1504 - val_loss: 0.3204
# Epoch 5/100
# 217/217 [==============================] - 35s 159ms/step - loss: 0.1488 - val_loss: 0.3182
# Epoch 6/100
# 217/217 [==============================] - 34s 159ms/step - loss: 0.1484 - val_loss: 0.3103
# Epoch 7/100
# 217/217 [==============================] - 35s 159ms/step - loss: 0.1460 - val_loss: 0.3193
# Epoch 8/100
# 217/217 [==============================] - 35s 161ms/step - loss: 0.1459 - val_loss: 0.3121
# Epoch 9/100
# 217/217 [==============================] - 35s 162ms/step - loss: 0.1453 - val_loss: 0.3087
# Epoch 10/100
# 217/217 [==============================] - 35s 162ms/step - loss: 0.1444 - val_loss: 0.3141
# Epoch 11/100
# 217/217 [==============================] - 35s 159ms/step - loss: 0.1446 - val_loss: 0.3156
# Epoch 12/100
# 217/217 [==============================] - 35s 160ms/step - loss: 0.1433 - val_loss: 0.3108
# Epoch 13/100
# 217/217 [==============================] - 35s 160ms/step - loss: 0.1428 - val_loss: 0.3105
# Epoch 14/100
# 217/217 [==============================] - 35s 161ms/step - loss: 0.1434 - val_loss: 0.3069
# Epoch 15/100
# 217/217 [==============================] - 35s 162ms/step - loss: 0.1420 - val_loss: 0.3115
# Epoch 16/100
# 217/217 [==============================] - 35s 160ms/step - loss: 0.1412 - val_loss: 0.3049
# Epoch 17/100
# 217/217 [==============================] - 35s 161ms/step - loss: 0.1396 - val_loss: 0.3056
# Epoch 18/100
# 217/217 [==============================] - 35s 161ms/step - loss: 0.1390 - val_loss: 0.3124
# Epoch 19/100
# 217/217 [==============================] - 35s 160ms/step - loss: 0.
100
# 217/217 [==============================] - 35s 161ms/step - loss: 0.1646 - val_loss: 0.3275
# Epoch 5/100
# 217/217 [==============================] - 34s 159ms/step - loss: 0.1639 - val_loss: 0.3271
# Epoch 6/100
# 217/217 [==============================] - 34s 159ms/step - loss: 0.1635 - val_loss: 0.3341
# Epoch 7/100
# 217/217 [==============================] - 34s 159ms/step - loss: 0.1627 - val_loss: 0.3264
# Epoch 8/100
# 217/217 [==============================] - 35s 161ms/step - loss: 0.1609 - val_loss: 0.3273
# Epoch 9/100
# 217/217 [==============================] - 35s 160ms/step - loss: 0.1610 - val_loss: 0.3240
# Epoch 10/100
# 217/217 [==============================] - 35s 161ms/step - loss: 0.1597 - val_loss: 0.3422
# Epoch 11/100
# 217/217 [==============================] - 34s 159ms/step - loss: 0.1600 - val_loss: 0.3340
# Epoch 12/100
# 217/217 [==============================] - 34s 159ms/step - loss: 0.1589 - val_loss: 0.3390
# Epoch 13/100
# 217/217 [==============================] - 34s 159ms/step - loss: 0.1578 - val_loss: 0.3328
# Epoch 14/100
# 217/217 [==============================] - 35s 161ms/step - loss: 0.1572 - val_loss: 0.3411
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x7f8417a98710> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x7f8417a98710> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# [[0.3774726986885071, 329.5101580619812], [0.2576304078102112, 317.5680809020996], [0.10476814210414886, 624.9277789592743], [0.0592956505715847, 335.75038290023804], [0.06946622580289841, 290.8102331161499], [0.19382649660110474, 309.30135583877563], [0.21224841475486755, 318.4884521961212], [0.09543122351169586, 493.1862289905548], [0.2106548249721527, 732.6710579395294], [0.17391516268253326, 657.8510887622833], [0.3115946352481842, 485.730614900589]]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /var/folders/ns/m6xqd78d419c4bs1hmdmhkh00000gp/T/ipykernel_36629/3099098967.py in <module>
#       6     #DataFrameの作成（欠損作成＆補完）
#       7
# ----> 8     inputs_df,labels_df,inputs_df_time,labels_df_time,select_features,n_input = init_df(target,imputation_select)
#       9
#      10     #単一値補完の描画
#
# /var/folders/ns/m6xqd78d419c4bs1hmdmhkh00000gp/T/ipykernel_36629/1085522079.py in init_df(target, imputation_select)
#      19     if imputation_select=="rf":
#      20         #RandomForest imputation
# ---> 21         inputs_df,labels_df = random_forest_imputation(inputs_df,labels_df,select_features)
#      22     elif imputation_select=="mean":
#      23         #mean imputation
#
# /var/folders/ns/m6xqd78d419c4bs1hmdmhkh00000gp/T/ipykernel_36629/1651844165.py in random_forest_imputation(inputs_df, labels_df, select_features)
#       2     rf = RandomForestRegressor(n_estimators=10, n_jobs=-1)
#       3     imp = IterativeImputer(random_state=0,estimator=rf)
# ----> 4     inputs_df = pd.DataFrame(imp.fit_transform(inputs_df),columns=select_features)
#       5     labels_df = pd.DataFrame(imp.fit_transform(labels_df))
#       6     return inputs_df,labels_df
#
# ~/opt/anaconda3/envs/pems/lib/python3.7/site-packages/sklearn/impute/_iterative.py in fit_transform(self, X, y)
#     668                     neighbor_feat_idx,
#     669                     estimator=None,
# --> 670                     fit_mode=True,
#     671                 )
#     672                 estimator_triplet = _ImputerTriplet(
#
# ~/opt/anaconda3/envs/pems/lib/python3.7/site-packages/sklearn/impute/_iterative.py in _impute_one_feature(self, X_filled, mask_missing_values, feat_idx, neighbor_feat_idx, estimator, fit_mode)
#     315             X_train = _safe_indexing(X_filled[:, neighbor_feat_idx], ~missing_row_mask)
#     316             y_train = _safe_indexing(X_filled[:, feat_idx], ~missing_row_mask)
# --> 317             estimator.fit(X_train, y_train)
#     318
#     319         # if no missing values, don't predict
#
# ~/opt/anaconda3/envs/pems/lib/python3.7/site-packages/sklearn/ensemble/_forest.py in fit(self, X, y, sample_weight)
#     465                     n_samples_bootstrap=n_samples_bootstrap,
#     466                 )
# --> 467                 for i, t in enumerate(trees)
#     468             )
#     469
#
# ~/opt/anaconda3/envs/pems/lib/python3.7/site-packages/joblib/parallel.py in __call__(self, iterable)
#    1054
#    1055             with self._backend.retrieval_context():
# -> 1056                 self.retrieve()
#    1057             # Make sure that we get a last message telling us we are done
#    1058             elapsed_time = time.time() - self._start_time
#
# ~/opt/anaconda3/envs/pems/lib/python3.7/site-packages/joblib/parallel.py in retrieve(self)
#     933             try:
#     934                 if getattr(self._backend, 'supports_timeout', False):
# --> 935                     self._output.extend(job.get(timeout=self.timeout))
#     936                 else:
#     937                     self._output.extend(job.get())
#
# ~/opt/anaconda3/envs/pems/lib/python3.7/multiprocessing/pool.py in get(self, timeout)
#     649
#     650     def get(self, timeout=None):
# --> 651         self.wait(timeout)
#     652         if not self.ready():
#     653             raise TimeoutError
#
# ~/opt/anaconda3/envs/pems/lib/python3.7/multiprocessing/pool.py in wait(self, timeout)
#     646
#     647     def wait(self, timeout=None):
# --> 648         self._event.wait(timeout)
#     649
#     650     def get(self, timeout=None):
#
# ~/opt/anaconda3/envs/pems/lib/python3.7/threading.py in wait(self, timeout)
#     550             signaled = self._flag
#     551             if not signaled:
# --> 552                 signaled = self._cond.wait(timeout)
#     553             return signaled
#     554
#
# ~/opt/anaconda3/envs/pems/lib/python3.7/threading.py in wait(self, timeout)
#     294         try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     295             if timeout is None:
# --> 296                 waiter.acquire()
#     297                 gotit = True
#     298             else:
#
# KeyboardInterrupt:

# %%
evaluation_df = pd.DataFrame(evaluation_list,index=df.columns,columns=["RMSE","training_time"])

dirname = excel_output_path
os.makedirs(dirname, exist_ok=True)
evaluation_df.to_excel(excel_output_path+"/RMSE.xlsx")
