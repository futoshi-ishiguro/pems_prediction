# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation
from tensorflow.keras.layers import LSTM
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
#csvのパスを設定
csv_path = "/Users/ishigurofutoshi/lab_materials/data/integrated_route.csv"

# %%
df = pd.read_csv(csv_path,index_col=0)
# Slice [start:stop:step], starting from index 5 take every 6th record.
#df = df[5::6]
df = df.dropna(axis=1)
date_time = pd.to_datetime(df.pop('5 Minutes'), format='%Y.%m.%d %H:%M:%S')

# %%
target = "11750"
n_input = 10
index_target = df.columns.get_loc(target)

# %%
df
# Out:
#        11750  13147  13867  14467  14987  16207  16507  16509  16510  16511  \
# 0      16.88  34.90   8.62  19.35   7.00  21.43  30.88  30.22  35.87  40.30
# 1      16.97  34.87   8.65  19.35   7.00  21.42  30.87  29.98  35.92  40.37
# 2      16.98  34.95   8.67  19.38   7.00  21.43  30.82  30.07  36.02  40.43
# 3      16.98  35.05   8.67  19.43   7.02  21.37  30.85  30.15  36.13  40.55
# 4      16.90  35.03   8.68  19.53   7.03  21.40  30.88  30.28  36.27  40.68
# ...      ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# 25567  17.15  35.30   8.60  19.42   7.22  21.57  30.62  30.30  36.15  40.72
# 25568  17.10  35.30   8.58  19.47   7.23  21.57  30.87  30.37  36.02  40.62
# 25569  17.32  35.28   8.60  19.43   7.22  21.82  31.45  31.00  36.17  40.82
# 25570  17.25  35.32   8.65  19.48   7.23  21.73  31.73  31.43  36.13  40.70
# 25571  17.20  35.32   8.63  19.50   7.23  21.83  31.63  31.40  36.15  40.75
#
#        ...     79     80     81     82     83     84     85     86     87  \
# 0      ...  30.15  29.38  36.30  35.93  11.78  11.87  16.80  16.73  15.92
# 1      ...  30.15  29.37  36.37  35.88  11.82  11.88  16.80  16.78  15.87
# 2      ...  30.17  29.27  36.23  35.88  11.82  12.07  16.83  16.77  15.85
# 3      ...  30.15  29.13  36.27  35.98  11.82  11.92  16.82  16.70  15.83
# 4      ...  29.97  29.02  36.37  36.08  11.85  11.92  16.83  16.73  15.88
# ...    ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# 25567  ...  30.65  30.08  36.03  36.00  11.78  12.03  16.82  17.02  15.52
# 25568  ...  30.68  30.13  35.95  36.07  11.78  12.05  16.90  17.10  15.73
# 25569  ...  30.52  30.03  36.02  35.98  11.82  12.00  16.87  17.17  15.63
# 25570  ...  30.67  29.90  35.97  36.03  11.82  12.07  16.90  17.65  15.82
# 25571  ...  30.95  29.83  36.05  36.10  11.82  12.07  17.18  17.30  15.80
#
#           88
# 0      12.12
# 1      12.12
# 2      12.15
# 3      12.18
# 4      12.17
# ...      ...
# 25567  12.78
# 25568  12.87
# 25569  12.78
# 25570  12.83
# 25571  12.85
#
# [80100 rows x 272 columns]

# %% [markdown]
# ## target missing

# %%
def select_index(target):

    #相互相関関数
    corrs = []
    lags = []
    for c in df.columns:
        xcorr_list = xcorr(df[target],df[c])
        lag = np.argmax(np.abs(xcorr_list))
        lags.append(lag)
        corr = corr_lag(df[target],df[c],lag)
        corrs.append(corr)
    corrs = np.array(corrs)
    lags = np.array(lags) #targetと各routeでのラグを格納
    
    #重要度の上位を出力
    idx_corrs = np.argsort(np.abs(corrs))[::-1]
    top_cols_corrs,top_importances_corrs,lags = df.columns.values[idx_corrs][1:n_input+1],corrs[idx_corrs][1:n_input+1],lags[idx_corrs][1:n_input+1]
    print(top_cols_corrs,top_importances_corrs,lags)
    
    #targetのインデックスを追加
    if target in top_cols_corrs:
        top_cols_corrs = np.delete(top_cols_corrs,[target])
    
    top_cols_select = top_cols_corrs
    
    return top_cols_select
    #return [str(target)]
    
def xcorr(target,c):
    xcorr_list = []
    #margin = np.zeros(24)
    #target = np.block([target,margin])
    #c = np.block([margin,c])
    
    for t in range(24):
        score = np.dot(target[t:],c[:len(c)-t])/(len(target)-t)
        xcorr_list.append(score)
        
    return xcorr_list

def corr_lag(target,c,lag):
    return np.corrcoef(target[lag:],c[:len(c)-lag])[0,1]

# %% [markdown]
# ## target not missing

# %% [markdown]
# def select_index(target):
#
#     #相互相関関数
#     corrs = []
#     lags = []
#     for c in df.columns:
#         xcorr_list = xcorr(df[target],df[c])
#         lag = np.argmax(np.abs(xcorr_list))
#         lags.append(lag)
#         corr = corr_lag(df[target],df[c],lag)
#         corrs.append(corr)
#     corrs = np.array(corrs)
#     lags = np.array(lags) #targetと各routeでのラグを格納
#
#     #重要度の上位を出力
#     idx_corrs = np.argsort(np.abs(corrs))[::-1]
#     top_cols_corrs,top_importances_corrs,lags = df.columns.values[idx_corrs][:n_input],corrs[idx_corrs][:n_input],lags[idx_corrs][:n_input]
#     print(top_cols_corrs,top_importances_corrs,lags)
#
#     #targetのインデックスを追加
#     if not target in top_cols_corrs:
#         top_cols_corrs = np.append(top_cols_corrs,[target])
#
#     top_cols_select = top_cols_corrs
#
#     return top_cols_select
#     #return [str(target)]
#
# def xcorr(target,c):
#     xcorr_list = []
#     #margin = np.zeros(24)
#     #target = np.block([target,margin])
#     #c = np.block([margin,c])
#
#     for t in range(24):
#         score = np.dot(target[t:],c[:len(c)-t])/(len(target)-t)
#         xcorr_list.append(score)
#
#     return xcorr_list
#
# def corr_lag(target,c,lag):
#     return np.corrcoef(target[lag:],c[:len(c)-lag])[0,1]

# %%
labels_df = df.loc[:,target]
inputs_df = df.loc[:,select_index(target)]
# Out:
# ['11750' '4649' '79' '6225' '18830' '81' '78' '4651' '18828' '6224'] [1.         0.9902075  0.96206984 0.840221   0.83876349 0.82030941
#  0.81900472 0.81898798 0.81583006 0.81549603] [0 0 3 1 1 1 3 0 4 4]

# %%
def make_dataset(labels_df,inputs_df,window_len):
    labels, inputs = [], []
    for i in range(len(labels_df)-window_len):
        labels.append(labels_df.iloc[i+window_len])
        inputs.append(inputs_df.iloc[i:i+window_len])
    re_labels = np.array(labels).reshape(len(labels),1)
    re_inputs = np.array(inputs).reshape(len(inputs),window_len,n_input)
    
    return re_labels,re_inputs

# %%
labels_ds, inputs_ds = make_dataset(labels_df,inputs_df,12)

# %%
labels_ds.shape
# Out:
# (80088, 1)

# %%
inputs_ds.shape
# Out:
# (80088, 12, 10)

# %%
n = len(inputs_ds)
train_x, test_x = inputs_ds[:int(n*0.9)],inputs_ds[int(n*0.9):] 
train_y, test_y = labels_ds[:int(n*0.9)],labels_ds[int(n*0.9):]

# %%
# モデル構築

# 1つの学習データのwindowサイズ
length_of_sequence = inputs_ds.shape[1] 
in_out_neurons = 1
n_hidden = 300

model = Sequential()
model.add(LSTM(n_hidden, batch_input_shape=(None, length_of_sequence, n_input), return_sequences=False))
model.add(Dense(in_out_neurons))
#model.add(Activation("linear"))
optimizer = Adam(learning_rate=0.001)
model.compile(loss="mean_squared_error", optimizer=optimizer)
# Out:
# 2022-04-22 15:23:56.056560: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
early_stopping = EarlyStopping(monitor='val_loss', mode='auto', patience=20)
model.fit(train_x, train_y,
          batch_size=300,
          epochs=100,
          validation_split=0.1,
          callbacks=[early_stopping]
          )
# Out:
# Epoch 1/100
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_train_function.<locals>.train_function at 0x7f89530a4e60> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_train_function.<locals>.train_function at 0x7f89530a4e60> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# 216/217 [============================>.] - ETA: 0s - loss: 19.3948WARNING:tensorflow:AutoGraph could not transform <function Model.make_test_function.<locals>.test_function at 0x7f897240d830> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_test_function.<locals>.test_function at 0x7f897240d830> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# 217/217 [==============================] - 25s 109ms/step - loss: 19.3764 - val_loss: 6.1444
# Epoch 2/100
# 217/217 [==============================] - 24s 109ms/step - loss: 1.2496 - val_loss: 1.5009
# Epoch 3/100
# 217/217 [==============================] - 24s 112ms/step - loss: 0.4826 - val_loss: 0.6579
# Epoch 4/100
# 217/217 [==============================] - 23s 107ms/step - loss: 0.3190 - val_loss: 0.4488
# Epoch 5/100
# 217/217 [==============================] - 22s 99ms/step - loss: 0.2441 - val_loss: 0.3463
# Epoch 6/100
# 217/217 [==============================] - 21s 99ms/step - loss: 0.2040 - val_loss: 0.3654
# Epoch 7/100
# 217/217 [==============================] - 21s 97ms/step - loss: 0.1798 - val_loss: 0.2927
# Epoch 8/100
# 217/217 [==============================] - 22s 100ms/step - loss: 0.1573 - val_loss: 0.2664
# Epoch 9/100
# 217/217 [==============================] - 21s 96ms/step - loss: 0.1728 - val_loss: 0.2612
# Epoch 10/100
# 217/217 [==============================] - 21s 98ms/step - loss: 0.1462 - val_loss: 0.1752
# Epoch 11/100
# 217/217 [==============================] - 21s 98ms/step - loss: 0.1182 - val_loss: 0.1725
# Epoch 12/100
# 217/217 [==============================] - 21s 99ms/step - loss: 0.1076 - val_loss: 0.1739
# Epoch 13/100
# 217/217 [==============================] - 22s 100ms/step - loss: 0.0997 - val_loss: 0.1913
# Epoch 14/100
# 217/217 [==============================] - 22s 100ms/step - loss: 0.0881 - val_loss: 0.2804
# Epoch 15/100
# 217/217 [==============================] - 23s 108ms/step - loss: 0.0850 - val_loss: 0.1783
# Epoch 16/100
# 217/217 [==============================] - 21s 96ms/step - loss: 0.0819 - val_loss: 0.1238
# Epoch 17/100
# 217/217 [==============================] - 20s 94ms/step - loss: 0.0461 - val_loss: 0.0588
# Epoch 76/100
# 217/217 [==============================] - 20s 91ms/step - loss: 0.0449 - val_loss: 0.0584
# Epoch 77/100
# 217/217 [==============================] - 20s 92ms/step - loss: 0.0445 - val_loss: 0.0700
# Epoch 78/100
# 217/217 [==============================] - 19s 87ms/step - loss: 0.0430 - val_loss: 0.0665
# Epoch 79/100
# 217/217 [==============================] - 19s 88ms/step - loss: 0.0441 - val_loss: 0.0594
# Epoch 80/100
# 217/217 [==============================] - 19s 88ms/step - loss: 0.0451 - val_loss: 0.0542
# Epoch 81/100
# 217/217 [==============================] - 19s 88ms/step - loss: 0.0437 - val_loss: 0.0569
# Epoch 82/100
# 217/217 [==============================] - 23s 105ms/step - loss: 0.0440 - val_loss: 0.0714
# Epoch 83/100
# 217/217 [==============================] - 20s 92ms/step - loss: 0.0481 - val_loss: 0.0571
# Epoch 84/100
# 217/217 [==============================] - 21s 96ms/step - loss: 0.0448 - val_loss: 0.0574
# Epoch 85/100
# 217/217 [==============================] - 22s 103ms/step - loss: 0.0446 - val_loss: 0.0550
# Epoch 86/100
# 217/217 [==============================] - 25s 117ms/step - loss: 0.0432 - val_loss: 0.0622
# Epoch 87/100
# 217/217 [==============================] - 20s 94ms/step - loss: 0.0436 - val_loss: 0.0582
# Epoch 88/100
# 217/217 [==============================] - 19s 86ms/step - loss: 0.0429 - val_loss: 0.0737
# Epoch 89/100
# 217/217 [==============================] - 18s 84ms/step - loss: 0.0433 - val_loss: 0.0574
# Epoch 90/100
# 217/217 [==============================] - 18s 84ms/step - loss: 0.0458 - val_loss: 0.0810
# Epoch 91/100
# 217/217 [==============================] - 18s 84ms/step - loss: 0.0429 - val_loss: 0.0676
# Epoch 92/100
# 217/217 [==============================] - 18s 84ms/step - loss: 0.0452 - val_loss: 0.0717
# Epoch 93/100
# 217/217 [==============================] - 18s 84ms/step - loss: 0.0417 - val_loss: 0.0986
# Epoch 94/100
# 217/217 [==============================] - 18s 84ms/step - loss: 0.0441 - val_loss: 0.0542
# Epoch 95/100
# 217/217 [==============================] - 18s 85ms/step - loss: 0.0424 - val_loss: 0.0645
# Epoch 96/100
# 217/217 [==============================] - 18s 84ms/step - loss: 0.0442 - val_loss: 0.0537
# Epoch 97/100
# 217/217 [==============================] - 19s 86ms/step - loss: 0.0426 - val_loss: 0.0800
# Epoch 98/100
# 217/217 [==============================] - 18s 84ms/step - loss: 0.0420 - val_loss: 0.0578
# Epoch 99/100
# 217/217 [==============================] - 18s 83ms/step - loss: 0.0437 - val_loss: 0.0939
# Epoch 100/100
# 217/217 [==============================] - 18s 83ms/step - loss: 0.0432 - val_loss: 0.0573

# %%
predicted = model.predict(test_x)

# %%
predicted
# Out:
# array([[17.648924],
#        [17.665827],
#        [17.686777],
#        ...,
#        [17.121595],
#        [17.266989],
#        [17.129213]], dtype=float32)

# %%
plt.plot(test_y[:100])
plt.plot(predicted[:100])

# %%
performance = model.evaluate(test_x,test_y, verbose=0)

# %%
performance
# Out:
# 0.31020134687423706
