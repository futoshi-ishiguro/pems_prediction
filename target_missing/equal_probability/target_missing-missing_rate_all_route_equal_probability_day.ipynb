# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation
from tensorflow.keras.layers import LSTM
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.ensemble import RandomForestRegressor
from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import IterativeImputer
from IPython.display import clear_output
import itertools
import time
import os

# %%
"""
imputation_select = {"rf","mean","mice"}
missing_rate
"""

imputation_select = "rf"
missing_rate = 0.4

# %%
#csvのパスを設定
csv_path = "/Users/ishigurofutoshi/lab_materials/data/integrated_route.csv"
#csv_path = "C:/Users/meida/lab_materials/pems/missing_data/pems_prediction/data/data/integrated_route.csv"

#output_path = "/Users/ishigurofutoshi/lab_materials/"+imputation_select
output_path = "C:/Users/meida/lab_materials/pems/missing_data/pems_prediction/output/equal_probability/correlation/day/"+imputation_select

fig_output_path = output_path+"/fig/"+str(missing_rate)
excel_output_path = output_path+"/excel"

# %%
df = pd.read_csv(csv_path,index_col=0)
# Slice [start:stop:step], starting from index 5 take every 6th record.
#df = df[5::6]
df = df.dropna(axis=1)
date_time = pd.to_datetime(df.pop('5 Minutes'), format='%Y.%m.%d %H:%M').reset_index(drop=True)

# %%
n_input = 10
n_min_ahead = 6
window_len = 24

plot_start = 900
plot_range = 100

# %%
df = df.reset_index(drop=True)

# %% [markdown]
# ### 標準化

# %%
column_indices = {name: i for i, name in enumerate(df.columns)}

n = len(df)
#train_df = df[0:int(n*0.9)]
#val_df = df[int(n*0.7):int(n*0.9)]
#test_df = df[int(n*0.9):]

num_features = df.shape[1]

# %%
df_mean = df.mean()
df_std = df.std()

df = (df - df_mean) / df_std
#val_df = (val_df - train_mean) / train_std
#test_df = (test_df - train_mean) / train_std

# %% [markdown]
# def select_index(df,target):
#     df_neighber = pd.read_csv("/Users/ishigurofutoshi/lab_materials/data/neighber_link.xlsx",header=None,index_col=0)
#     index = df_neighber.loc[target,:]
#     return index

# %%
def select_index(df,target):

    corrs = []
    for c in df.columns:
        corr = np.corrcoef(df[target],df[c])[0,1]
        corrs.append(corr)
    corrs = np.array(corrs)
    
    #重要度の上位を出力
    idx_corrs = np.argsort(np.abs(corrs))[::-1]
    top_cols_corrs,top_importances_corrs = df.columns.values[idx_corrs][:n_input],corrs[idx_corrs][:n_input]
    print(top_cols_corrs,top_importances_corrs)
    
    #targetのインデックスを追加
    if not target in top_cols_corrs:
        top_cols_corrs = np.append(top_cols_corrs,[target])
    
    top_cols_select = top_cols_corrs
    
    return top_cols_select

# %%
import datetime
day_index = []
for i in range(int(len(date_time)*0.9),len(date_time)):
    for d in range(1,32):
        for h in range(6,12):
            for m in range(0,60,5):
                if date_time[i] == datetime.datetime(2021,7,d,h,m,0):
                    day_index.append(i)

# %%
def init_df(target,imputation_select):
    select_features = select_index(df,target)
    
    df_for_target = df.loc[:,select_features]
    
    labels_df_time = pd.concat((date_time,df_for_target.loc[:,target]),axis=1,sort=False)
    inputs_df_time = pd.concat((date_time,df_for_target.loc[:,select_features]),axis=1,sort=False)
    
    for t in range(24):
        for i in labels_df_time.iloc[:int(80100*0.9)].loc[labels_df_time["5 Minutes"].dt.hour==t].sample(frac=missing_rate).index:
            labels_df_time.loc[i,target] = np.nan
        for route in select_features:
            for i in inputs_df_time.loc[inputs_df_time["5 Minutes"].dt.hour==t].sample(frac=missing_rate).index:
                inputs_df_time.loc[i,route] = np.nan
                
    inputs_df = inputs_df_time.drop(["5 Minutes"],axis=1)
    labels_df = labels_df_time.drop(["5 Minutes"],axis=1)

    if imputation_select=="rf":
        #RandomForest imputation
        inputs_df,labels_df = random_forest_imputation(inputs_df,labels_df,select_features)
    elif imputation_select=="mean":
        #mean imputation
        inputs_df,labels_df = mean_imputation(inputs_df,labels_df)
        
    elif imputation_select=="mice":
        #MICE
        inputs_df,labels_df = mice_imputation(inputs_df,labels_df,select_features)
    
    return inputs_df,labels_df,inputs_df_time,labels_df_time,select_features

# %%
def random_forest_imputation(inputs_df,labels_df,select_features):
    rf = RandomForestRegressor(n_estimators=10, n_jobs=-1)
    imp = IterativeImputer(random_state=0,estimator=rf)
    inputs_df = pd.DataFrame(imp.fit_transform(inputs_df),columns=select_features)
    labels_df = pd.DataFrame(imp.fit_transform(labels_df))
    return inputs_df,labels_df

# %%
def mean_imputation(inputs_df,labels_df):
    inputs_df = inputs_df.fillna(inputs_df.mean())
    labels_df = labels_df.fillna(labels_df.mean())
    return inputs_df,labels_df

# %%
from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import IterativeImputer

def mice_imputation(inputs_df,labels_df,select_features):
    imp = IterativeImputer(max_iter=10, random_state=0, sample_posterior=True,tol=0.0001)
    inputs_df = pd.DataFrame(imp.fit_transform(inputs_df),columns=select_features)
    labels_df = pd.DataFrame(imp.fit_transform(labels_df))
    return inputs_df,labels_df

# %%
def show_imputation(target,inputs_df,select_features):
    original = df[target].values
    imputation = inputs_df[target].values
    
    plt.figure(figsize=(15,10))

    plt.scatter(range(30),original[:30],color="blue")
    plt.scatter(range(30),imputation[:30],color="red")
    
    dirname = fig_output_path+"/imputation/"
    os.makedirs(dirname, exist_ok=True)
    plt.savefig(dirname+target+".png")

    plt.show()

# %%
def make_dataset(labels_df,inputs_df,window_len):
    labels, inputs = [], []
    for i in range(len(labels_df)-(window_len+n_min_ahead-1)):
        labels.append(labels_df.iloc[i+window_len+n_min_ahead-1])
        inputs.append(inputs_df.iloc[i:i+window_len])
    re_labels = np.array(labels).reshape(len(labels),1)
    re_inputs = np.array(inputs).reshape(len(inputs),window_len,n_input)
    
    return re_labels,re_inputs

# %%
def show_prediction(test_y,predicted):
    plt.figure(figsize=(15,10))

    plt.plot(test_y[plot_start:plot_start+plot_range],color="blue")
    plt.plot(predicted[plot_start:plot_start+plot_range],color="orange")
    
    dirname = fig_output_path+"/prediction/"
    os.makedirs(dirname, exist_ok=True)
    plt.savefig(dirname+target+".png")

# %%
def show_missing_position(test_y,labels_df_time,select_features):
    NaN_position = [np.nan for i in range(len(test_y))]
    measured_position = [np.nan for i in range(len(test_y))]
    tmp = list(itertools.chain.from_iterable(test_y))

    for i in range(len(test_y)):
        if np.isnan(labels_df_time.iloc[i,1]):
            NaN_position[i] = tmp[i]
        else:
            measured_position[i] = tmp[i]
    NaN_mask = [[0 for i in range(len(select_features))] for j in range(len(test_x[plot_start:plot_start+plot_range,:]))]

    c_num = 0
    for c in select_features:
        for i in range(len(test_x[plot_start:plot_start+plot_range,:])):
            if np.isnan(inputs_df_time[c].iloc[int(n*0.9)+plot_start+i,]):
                NaN_mask[i][c_num] = 1
        c_num += 1

    NaN_mask = np.array(NaN_mask)
    NaN_mask_df = pd.DataFrame(data=NaN_mask.T,index=select_features,columns=inputs_df_time["5 Minutes"].iloc[int(n*0.9)+plot_start:int(n*0.9)+plot_start+plot_range,].dt.strftime("%Y/%m/%d-%H:%M"))
    
    plt.figure(figsize=(15,10))
    sns.set(rc={"figure.figsize":(15,3)})
    sns.heatmap(NaN_mask_df,cmap="Reds",cbar=False)
    
    dirname = fig_output_path+"/missing_position/"
    os.makedirs(dirname, exist_ok=True)
    plt.savefig(dirname+target+".png")

# %%
def evaluation(evaluation_list,training_time):
    performance = model.evaluate(test_x,test_y, verbose=0)
    evaluation_list.append([performance,training_time])
    
    return evaluation_list

# %%
evaluation_list = []
for target in df.columns:
    index_target = df.columns.get_loc(target)
    
    #DataFrameの作成（欠損作成＆補完）

    inputs_df,labels_df,inputs_df_time,labels_df_time,select_features = init_df(target,imputation_select)
    
    #単一値補完の描画
    show_imputation(target,inputs_df,select_features)
    
    labels_ds, inputs_ds = make_dataset(labels_df,inputs_df,window_len)
    
    n = len(inputs_ds)
    train_x, test_x = inputs_ds[:int(n*0.9)],inputs_ds[day_index]
    train_y, test_y = labels_ds[:int(n*0.9)],labels_ds[day_index]
    
    # モデル構築
    # 1つの学習データのwindowサイズ
    length_of_sequence = inputs_ds.shape[1] 
    in_out_neurons = 1
    n_hidden = 300

    model = Sequential()
    #model.add(LSTM(n_hidden, batch_input_shape=(None, length_of_sequence, n_input), return_sequences=True))
    #model.add(LSTM(n_hidden, batch_input_shape=(None, length_of_sequence, n_input), return_sequences=True))
    model.add(LSTM(n_hidden, batch_input_shape=(None, length_of_sequence, n_input), return_sequences=False))
    model.add(Dense(in_out_neurons))
    #model.add(Activation("linear"))
    optimizer = Adam(learning_rate=0.001)
    model.compile(loss="mean_squared_error", optimizer=optimizer)
    
    early_stopping = EarlyStopping(monitor='val_loss', mode='auto', patience=5)
    
    start = time.time()
    model.fit(train_x, train_y,
          batch_size=300,
          epochs=100,
          validation_split=0.1,
          callbacks=[early_stopping]
          )
    training_time = time.time()-start
    
    #モデルテスト
    predicted = model.predict(test_x)
    
    #予測値と観測値の描画
    show_prediction(test_y,predicted)
    
    #欠損値の描画
    show_missing_position(test_y,labels_df_time,select_features)
    
    #評価結果の出力
    evaluation_list = evaluation(evaluation_list,training_time)
    print(evaluation_list)
# Out:
# ['11750' '4649' '79' '6225' '18830' '81' '4651' '275' '78' '18828'] [1.         0.9902075  0.94140911 0.83968254 0.83840499 0.82003342
#  0.81898798 0.81518512 0.81346402 0.80680353]
# /Users/ishigurofutoshi/opt/anaconda3/envs/pems/lib/python3.7/site-packages/sklearn/impute/_iterative.py:701: ConvergenceWarning: [IterativeImputer] Early stopping criterion not reached.
#   ConvergenceWarning,
# 2022-09-21 17:19:17.223646: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Epoch 1/100
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_train_function.<locals>.train_function at 0x7f803acc6710> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_train_function.<locals>.train_function at 0x7f803acc6710> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# 216/217 [============================>.] - ETA: 0s - loss: 0.2413WARNING:tensorflow:AutoGraph could not transform <function Model.make_test_function.<locals>.test_function at 0x7f803ae49cb0> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_test_function.<locals>.test_function at 0x7f803ae49cb0> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# 217/217 [==============================] - 37s 163ms/step - loss: 0.2412 - val_loss: 0.5041
# Epoch 2/100
# 217/217 [==============================] - 35s 163ms/step - loss: 0.2327 - val_loss: 0.4965
# Epoch 3/100
# 217/217 [==============================] - 35s 162ms/step - loss: 0.2294 - val_loss: 0.4922
# Epoch 4/100
# 217/217 [==============================] - 35s 161ms/step - loss: 0.2284 - val_loss: 0.4893
# Epoch 5/100
# 217/217 [==============================] - 36s 168ms/step - loss: 0.2292 - val_loss: 0.4919
# Epoch 6/100
# 217/217 [==============================] - 35s 162ms/step - loss: 0.2282 - val_loss: 0.4905
# Epoch 7/100
# 217/217 [==============================] - 35s 161ms/step - loss: 0.2273 - val_loss: 0.4945
# Epoch 8/100
# 217/217 [==============================] - 37s 169ms/step - loss: 0.2287 - val_loss: 0.5227
# Epoch 9/100
# 217/217 [==============================] - 37s 171ms/step - loss: 0.2261 - val_loss: 0.4896
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x7f803b0b5c20> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x7f803b0b5c20> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# [[0.7896251678466797, 323.21628189086914]]
# ['13147' '82' '16207' '415' '2133' '4650' '6224' '18828' '414' '274'] [1.         0.94864504 0.88570701 0.8652955  0.84972894 0.84914305
#  0.84231115 0.83930547 0.82916247 0.82113285]
# /Users/ishigurofutoshi/opt/anaconda3/envs/pems/lib/python3.7/site-packages/sklearn/impute/_iterative.py:701: ConvergenceWarning: [IterativeImputer] Early stopping criterion not reached.
#   ConvergenceWarning,
# Epoch 1/100
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_train_function.<locals>.train_function at 0x7f815c095200> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_train_function.<locals>.train_function at 0x7f815c095200> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# 216/217 [============================>.] - ETA: 0s - loss: 0.2464WARNING:tensorflow:AutoGraph could not transform <function Model.make_test_function.<locals>.test_function at 0x7f802c3bcf80> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_test_function.<locals>.test_function at 0x7f802c3bcf80> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# 217/217 [==============================] - 36s 158ms/step - loss: 0.2465 - val_loss: 0.5445
# Epoch 2/100
# 217/217 [==============================] - 34s 158ms/step - loss: 0.2393 - val_loss: 0.5371
# Epoch 3/100
# 217/217 [==============================] - 35s 162ms/step - loss: 0.2369 - val_loss: 0.5312
# Epoch 4/100
# 217/217 [==============================] - 36s 166ms/step - loss: 0.2362 - val_loss: 0.5358
# Epoch 5/100
# 217/217 [==============================] - 35s 163ms/step - loss: 0.2347 - val_loss: 0.5338
# Epoch 6/100
# 217/217 [==============================] - 35s 163ms/step - loss: 0.2338 - val_loss: 0.5289
# Epoch 7/100
# 217/217 [==============================] - 36s 164ms/step - loss: 0.2330 - val_loss: 0.5340
# Epoch 8/100
# 217/217 [==============================] - 36s 166ms/step - loss: 0.2321 - val_loss: 0.5378
# Epoch 9/100
# 217/217 [==============================] - 36s 167ms/step - loss: 0.2310 - val_loss: 0.5391
# Epoch 10/100
# 217/217 [==============================] - 37s 168ms/step - loss: 0.2308 - val_loss: 0.5362
# Epoch 11/100
# 217/217 [==============================] - 37s 170ms/step - loss: 0.2293 - val_loss: 0.5438
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x7f802bdf7050> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x7f802bdf7050> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# [[0.7896251678466797, 323.21628189086914], [0.7056500315666199, 393.75567603111267]]
# ['13867' '365' '83' '271' '6212' '19837' '2135' '6215' '18840' '4647'] [1.         0.99845455 0.99446449 0.99325247 0.94069222 0.93707383
#  0.92759085 0.92226633 0.92171935 0.92167601]
# /Users/ishigurofutoshi/opt/anaconda3/envs/pems/lib/python3.7/site-packages/sklearn/impute/_iterative.py:701: ConvergenceWarning: [IterativeImputer] Early stopping criterion not reached.
#   ConvergenceWarning,
# Epoch 1/100
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_train_function.<locals>.train_function at 0x7f802bd1b5f0> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_train_function.<locals>.train_function at 0x7f802bd1b5f0> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# 216/217 [============================>.] - ETA: 0s - loss: 0.2509WARNING:tensorflow:AutoGraph could not transform <function Model.make_test_function.<locals>.test_function at 0x7f802c0dfef0> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_test_function.<locals>.test_function at 0x7f802c0dfef0> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# 217/217 [==============================] - 35s 155ms/step - loss: 0.2508 - val_loss: 0.3158
# Epoch 2/100
# 217/217 [==============================] - 34s 156ms/step - loss: 0.2435 - val_loss: 0.3139
# Epoch 3/100
# 217/217 [==============================] - 35s 163ms/step - loss: 0.2430 - val_loss: 0.3123
# Epoch 4/100
# 217/217 [==============================] - 36s 164ms/step - loss: 0.2421 - val_loss: 0.3118
# Epoch 5/100
# 217/217 [==============================] - 36s 166ms/step - loss: 0.2418 - val_loss: 0.3126
# Epoch 6/100
# 217/217 [==============================] - 37s 170ms/step - loss: 0.2408 - val_loss: 0.3129
# Epoch 7/100
# 217/217 [==============================] - 36s 166ms/step - loss: 0.2403 - val_loss: 0.3150
# Epoch 8/100
# 217/217 [==============================] - 37s 169ms/step - loss: 0.2398 - val_loss: 0.3131
# Epoch 9/100
# 217/217 [==============================] - 37s 169ms/step - loss: 0.2398 - val_loss: 0.3176
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x7f803b03dcb0> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x7f803b03dcb0> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# [[0.7896251678466797, 323.21628189086914], [0.7056500315666199, 393.75567603111267], [0.034592948853969574, 322.0106189250946]]
# ['14467' '372' '19835' '19837' '6225' '77' '18830' '271' '16509' '18828'] [1.         0.97521698 0.9613575  0.90893136 0.88850983 0.88720818
#  0.88715722 0.88655182 0.88475364 0.88382605]
# /Users/ishigurofutoshi/opt/anaconda3/envs/pems/lib/python3.7/site-packages/sklearn/impute/_iterative.py:701: ConvergenceWarning: [IterativeImputer] Early stopping criterion not reached.
#   ConvergenceWarning,
# Epoch 1/100
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_train_function.<locals>.train_function at 0x7f802bf13e60> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_train_function.<locals>.train_function at 0x7f802bf13e60> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# 216/217 [============================>.] - ETA: 0s - loss: 0.2759WARNING:tensorflow:AutoGraph could not transform <function Model.make_test_function.<locals>.test_function at 0x7f815c2def80> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_test_function.<locals>.test_function at 0x7f815c2def80> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# 217/217 [==============================] - 35s 157ms/step - loss: 0.2758 - val_loss: 0.3453
# Epoch 2/100
# 217/217 [==============================] - 35s 161ms/step - loss: 0.2658 - val_loss: 0.3483
# Epoch 3/100
# 217/217 [==============================] - 43s 197ms/step - loss: 0.2629 - val_loss: 0.3489
# Epoch 4/100
# 217/217 [==============================] - 51s 236ms/step - loss: 0.2620 - val_loss: 0.3463
# Epoch 5/100
# 217/217 [==============================] - 43s 200ms/step - loss: 0.2615 - val_loss: 0.3507
# Epoch 6/100
# 217/217 [==============================] - 39s 181ms/step - loss: 0.2617 - val_loss: 0.3483
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x7f803dd70200> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x7f803dd70200> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# [[0.7896251678466797, 323.21628189086914], [0.7056500315666199, 393.75567603111267], [0.034592948853969574, 322.0106189250946], [0.12147105485200882, 247.19731307029724]]
# ['14987' '18840' '6212' '6647' '6648' '471' '2135' '16510' '83' '16511'] [1.         0.95668237 0.95297776 0.93946296 0.91552268 0.88703146
#  0.88319655 0.88308112 0.88251415 0.87996836]
# /Users/ishigurofutoshi/opt/anaconda3/envs/pems/lib/python3.7/site-packages/sklearn/impute/_iterative.py:701: ConvergenceWarning: [IterativeImputer] Early stopping criterion not reached.
#   ConvergenceWarning,
# Epoch 1/100
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_train_function.<locals>.train_function at 0x7f802bdf75f0> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_train_function.<locals>.train_function at 0x7f802bdf75f0> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# 217/217 [==============================] - ETA: 0s - loss: 0.2761WARNING:tensorflow:AutoGraph could not transform <function Model.make_test_function.<locals>.test_function at 0x7f803ae490e0> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_test_function.<locals>.test_function at 0x7f803ae490e0> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# 217/217 [==============================] - 38s 168ms/step - loss: 0.2761 - val_loss: 0.5063
# Epoch 2/100
# 217/217 [==============================] - 40s 186ms/step - loss: 0.2622 - val_loss: 0.4826
# Epoch 3/100
# 217/217 [==============================] - 43s 196ms/step - loss: 0.2598 - val_loss: 0.4842
# Epoch 4/100
# 217/217 [==============================] - 41s 191ms/step - loss: 0.2593 - val_loss: 0.4952
# Epoch 5/100
# 217/217 [==============================] - 40s 185ms/step - loss: 0.2582 - val_loss: 0.4826
# Epoch 6/100
# 217/217 [==============================] - 39s 181ms/step - loss: 0.2563 - val_loss: 0.4953
# Epoch 7/100
# 217/217 [==============================] - 41s 189ms/step - loss: 0.2566 - val_loss: 0.4815
# Epoch 8/100
# 217/217 [==============================] - 41s 190ms/step - loss: 0.2540 - val_loss: 0.4959
# Epoch 9/100
# 217/217 [==============================] - 44s 201ms/step - loss: 0.2543 - val_loss: 0.4822
# Epoch 10/100
# 217/217 [==============================] - 39s 182ms/step - loss: 0.2510 - val_loss: 0.4953
# Epoch 11/100
# 217/217 [==============================] - 39s 178ms/step - loss: 0.2506 - val_loss: 0.4940
# Epoch 12/100
# 217/217 [==============================] - 40s 182ms/step - loss: 0.2484 - val_loss: 0.4830
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x7f803aeb0050> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x7f803aeb0050> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# [[0.7896251678466797, 323.21628189086914], [0.7056500315666199, 393.75567603111267], [0.034592948853969574, 322.0106189250946], [0.12147105485200882, 247.19731307029724], [0.06978099793195724, 485.439013004303]]
# ['16207' '13147' '4650' '2133' '274' '472' '377' '6224' '82' '18828'] [1.         0.88570701 0.85521216 0.85261947 0.83281609 0.83263535
#  0.82377736 0.80846684 0.80418712 0.79806113]
# /Users/ishigurofutoshi/opt/anaconda3/envs/pems/lib/python3.7/site-packages/sklearn/impute/_iterative.py:701: ConvergenceWarning: [IterativeImputer] Early stopping criterion not reached.
#   ConvergenceWarning,
# Epoch 1/100
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_train_function.<locals>.train_function at 0x7f802bfd44d0> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_train_function.<locals>.train_function at 0x7f802bfd44d0> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# 216/217 [============================>.] - ETA: 0s - loss: 0.2679WARNING:tensorflow:AutoGraph could not transform <function Model.make_test_function.<locals>.test_function at 0x7f803b194c20> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_test_function.<locals>.test_function at 0x7f803b194c20> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# 217/217 [==============================] - 36s 158ms/step - loss: 0.2678 - val_loss: 0.5246
# Epoch 2/100
# 217/217 [==============================] - 36s 168ms/step - loss: 0.2581 - val_loss: 0.5376
# Epoch 3/100
# 217/217 [==============================] - 36s 168ms/step - loss: 0.2571 - val_loss: 0.5147
# Epoch 4/100
# 217/217 [==============================] - 36s 166ms/step - loss: 0.2551 - val_loss: 0.5247
# Epoch 5/100
# 217/217 [==============================] - 36s 167ms/step - loss: 0.2543 - val_loss: 0.5177
# Epoch 6/100
# 217/217 [==============================] - 37s 168ms/step - loss: 0.2531 - val_loss: 0.5518
# Epoch 7/100
# 217/217 [==============================] - 41s 189ms/step - loss: 0.2534 - val_loss: 0.5169
# Epoch 8/100
# 217/217 [==============================] - 40s 182ms/step - loss: 0.2524 - val_loss: 0.5135
# Epoch 9/100
# 217/217 [==============================] - 40s 183ms/step - loss: 0.2514 - val_loss: 0.5221
# Epoch 10/100
# 217/217 [==============================] - 37s 171ms/step - loss: 0.2510 - val_loss: 0.5245
# Epoch 11/100
# 217/217 [==============================] - 41s 187ms/step - loss: 0.2496 - val_loss: 0.5209
# Epoch 12/100
# 217/217 [==============================] - 37s 170ms/step - loss: 0.2494 - val_loss: 0.5292
# Epoch 13/100
# 217/217 [==============================] - 39s 182ms/step - loss: 0.2478 - val_loss: 0.5216
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x7f802bdf7680> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x7f802bdf7680> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# [[0.7896251678466797, 323.21628189086914], [0.7056500315666199, 393.75567603111267], [0.034592948853969574, 322.0106189250946], [0.12147105485200882, 247.19731307029724], [0.06978099793195724, 485.439013004303], [0.7203347682952881, 491.68770813941956]]
# ['16507' '18174' '16509' '6210' '18872' '16511' '16510' '18830' '6225'
#  '6212'] [1.         0.97042622 0.96028951 0.94894831 0.94506445 0.93858044
#  0.93449565 0.89709137 0.89657327 0.8935393 ]
# /Users/ishigurofutoshi/opt/anaconda3/envs/pems/lib/python3.7/site-packages/sklearn/impute/_iterative.py:701: ConvergenceWarning: [IterativeImputer] Early stopping criterion not reached.
#   ConvergenceWarning,
# Epoch 1/100
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_train_function.<locals>.train_function at 0x7f803dd70b90> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_train_function.<locals>.train_function at 0x7f803dd70b90> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# 216/217 [============================>.] - ETA: 0s - loss: 0.2333WARNING:tensorflow:AutoGraph could not transform <function Model.make_test_function.<locals>.test_function at 0x7f803ae49050> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_test_function.<locals>.test_function at 0x7f803ae49050> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# 217/217 [==============================] - 40s 175ms/step - loss: 0.2332 - val_loss: 0.4554
# Epoch 2/100
# 217/217 [==============================] - 42s 191ms/step - loss: 0.2254 - val_loss: 0.4551
# Epoch 3/100
# 217/217 [==============================] - 38s 174ms/step - loss: 0.2232 - val_loss: 0.4636
# Epoch 4/100
# 217/217 [==============================] - 40s 184ms/step - loss: 0.2239 - val_loss: 0.4592
# Epoch 5/100
# 217/217 [==============================] - 41s 188ms/step - loss: 0.2225 - val_loss: 0.4530
# Epoch 6/100
# 217/217 [==============================] - 40s 185ms/step - loss: 0.2231 - val_loss: 0.4514
# Epoch 7/100
# 217/217 [==============================] - 37s 168ms/step - loss: 0.2216 - val_loss: 0.4501
# Epoch 8/100
# 217/217 [==============================] - 36s 168ms/step - loss: 0.2211 - val_loss: 0.4570
# Epoch 9/100
# 217/217 [==============================] - 36s 167ms/step - loss: 0.2207 - val_loss: 0.4659
# Epoch 10/100
# 217/217 [==============================] - 38s 177ms/step - loss: 0.2211 - val_loss: 0.4571
# Epoch 11/100
# 217/217 [==============================] - 36s 167ms/step - loss: 0.2200 - val_loss: 0.4493
# Epoch 12/100
# 217/217 [==============================] - 39s 181ms/step - loss: 0.2196 - val_loss: 0.4518
# Epoch 13/100
# 217/217 [==============================] - 38s 174ms/step - loss: 0.2195 - val_loss: 0.4542
# Epoch 14/100
# 217/217 [==============================] - 37s 169ms/step - loss: 0.2190 - val_loss: 0.4533
# Epoch 15/100
# 217/217 [==============================] - 36s 168ms/step - loss: 0.2181 - val_loss: 0.4640
# Epoch 16/100
# 217/217 [==============================] - 38s 176ms/step - loss: 0.2179 - val_loss: 0.4512
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x7f803af18b90> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x7f803af18b90> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# [[0.7896251678466797, 323.21628189086914], [0.7056500315666199, 393.75567603111267], [0.034592948853969574, 322.0106189250946], [0.12147105485200882, 247.19731307029724], [0.06978099793195724, 485.439013004303], [0.7203347682952881, 491.68770813941956], [0.2789756655693054, 611.9784109592438]]
# ['16509' '16507' '18174' '6212' '18840' '16511' '16510' '271' '83' '14467'] [1.         0.96028951 0.93248522 0.92588887 0.91826063 0.89913802
#  0.8933302  0.88919349 0.88589761 0.88475364]
# /Users/ishigurofutoshi/opt/anaconda3/envs/pems/lib/python3.7/site-packages/sklearn/impute/_iterative.py:701: ConvergenceWarning: [IterativeImputer] Early stopping criterion not reached.
#   ConvergenceWarning,
# Epoch 1/100
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_train_function.<locals>.train_function at 0x7f803b17e290> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_train_function.<locals>.train_function at 0x7f803b17e290> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# 216/217 [============================>.] - ETA: 0s - loss: 0.2565WARNING:tensorflow:AutoGraph could not transform <function Model.make_test_function.<locals>.test_function at 0x7f815c095560> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_test_function.<locals>.test_function at 0x7f815c095560> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# 217/217 [==============================] - 39s 175ms/step - loss: 0.2564 - val_loss: 0.4067
# Epoch 2/100
# 217/217 [==============================] - 41s 189ms/step - loss: 0.2482 - val_loss: 0.4041
# Epoch 3/100
# 217/217 [==============================] - 37s 171ms/step - loss: 0.2463 - val_loss: 0.4095
# Epoch 4/100
# 217/217 [==============================] - 40s 182ms/step - loss: 0.2462 - val_loss: 0.4016
# Epoch 5/100
# 217/217 [==============================] - 44s 202ms/step - loss: 0.2460 - val_loss: 0.4028
# Epoch 6/100
# 217/217 [==============================] - 41s 191ms/step - loss: 0.2448 - val_loss: 0.4034
# Epoch 7/100
# 217/217 [==============================] - 39s 178ms/step - loss: 0.2454 - val_loss: 0.4018
# Epoch 8/100
# 217/217 [==============================] - 38s 177ms/step - loss: 0.2446 - val_loss: 0.4142
# Epoch 9/100
# 217/217 [==============================] - 42s 192ms/step - loss: 0.2435 - val_loss: 0.4031
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x7f804dfd6c20> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x7f804dfd6c20> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# [[0.7896251678466797, 323.21628189086914], [0.7056500315666199, 393.75567603111267], [0.034592948853969574, 322.0106189250946], [0.12147105485200882, 247.19731307029724], [0.06978099793195724, 485.439013004303], [0.7203347682952881, 491.68770813941956], [0.2789756655693054, 611.9784109592438], [0.25344130396842957, 360.93927478790283]]
# ['16510' '16511' '471' '6712' '16507' '4651' '2135' '18830' '6210' '6225'] [1.         0.99813111 0.94203874 0.93665732 0.93449565 0.93405745
#  0.92481159 0.92464761 0.92277086 0.92243417]
# /Users/ishigurofutoshi/opt/anaconda3/envs/pems/lib/python3.7/site-packages/sklearn/impute/_iterative.py:701: ConvergenceWarning: [IterativeImputer] Early stopping criterion not reached.
#   ConvergenceWarning,
# Epoch 1/100
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_train_function.<locals>.train_function at 0x7f804dd59d40> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_train_function.<locals>.train_function at 0x7f804dd59d40> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# 217/217 [==============================] - ETA: 0s - loss: 0.2199WARNING:tensorflow:AutoGraph could not transform <function Model.make_test_function.<locals>.test_function at 0x7f802c036560> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_test_function.<locals>.test_function at 0x7f802c036560> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# 217/217 [==============================] - 39s 174ms/step - loss: 0.2199 - val_loss: 0.4654
# Epoch 2/100
# 217/217 [==============================] - 38s 173ms/step - loss: 0.2129 - val_loss: 0.4707
# Epoch 3/100
# 217/217 [==============================] - 37s 172ms/step - loss: 0.2129 - val_loss: 0.4718
# Epoch 4/100
# 217/217 [==============================] - 38s 174ms/step - loss: 0.2118 - val_loss: 0.4562
# Epoch 5/100
# 217/217 [==============================] - 37s 172ms/step - loss: 0.2117 - val_loss: 0.4567
# Epoch 6/100
# 217/217 [==============================] - 39s 178ms/step - loss: 0.2106 - val_loss: 0.4565
# Epoch 7/100
# 217/217 [==============================] - 37s 170ms/step - loss: 0.2107 - val_loss: 0.4636
# Epoch 8/100
# 217/217 [==============================] - 38s 175ms/step - loss: 0.2100 - val_loss: 0.4763
# Epoch 9/100
# 217/217 [==============================] - 38s 174ms/step - loss: 0.2102 - val_loss: 0.4584
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x7f803af41170> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x7f803af41170> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# [[0.7896251678466797, 323.21628189086914], [0.7056500315666199, 393.75567603111267], [0.034592948853969574, 322.0106189250946], [0.12147105485200882, 247.19731307029724], [0.06978099793195724, 485.439013004303], [0.7203347682952881, 491.68770813941956], [0.2789756655693054, 611.9784109592438], [0.25344130396842957, 360.93927478790283], [0.1510688066482544, 340.78828501701355]]
# ['16511' '16510' '16507' '471' '4651' '6712' '18830' '6225' '6210' '2135'] [1.         0.99813111 0.93858044 0.93646271 0.93296007 0.93051272
#  0.92725654 0.92518889 0.92160441 0.92066655]
# /Users/ishigurofutoshi/opt/anaconda3/envs/pems/lib/python3.7/site-packages/sklearn/impute/_iterative.py:701: ConvergenceWarning: [IterativeImputer] Early stopping criterion not reached.
#   ConvergenceWarning,
# Epoch 1/100
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_train_function.<locals>.train_function at 0x7f803b10fcb0> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_train_function.<locals>.train_function at 0x7f803b10fcb0> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# 216/217 [============================>.] - ETA: 0s - loss: 0.2235WARNING:tensorflow:AutoGraph could not transform <function Model.make_test_function.<locals>.test_function at 0x7f802bdf7560> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_test_function.<locals>.test_function at 0x7f802bdf7560> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# 217/217 [==============================] - 36s 159ms/step - loss: 0.2236 - val_loss: 0.4697
# Epoch 2/100
# 217/217 [==============================] - 35s 163ms/step - loss: 0.2119 - val_loss: 0.4671
# Epoch 3/100
# 217/217 [==============================] - 37s 169ms/step - loss: 0.2107 - val_loss: 0.4730
# Epoch 4/100
# 217/217 [==============================] - 36s 165ms/step - loss: 0.2092 - val_loss: 0.4696
# Epoch 5/100
# 217/217 [==============================] - 36s 165ms/step - loss: 0.2095 - val_loss: 0.4657
# Epoch 6/100
# 217/217 [==============================] - 36s 166ms/step - loss: 0.2090 - val_loss: 0.4706
# Epoch 7/100
# 217/217 [==============================] - 36s 167ms/step - loss: 0.2082 - val_loss: 0.4700
# Epoch 8/100
# 217/217 [==============================] - 36s 166ms/step - loss: 0.2080 - val_loss: 0.4703
# Epoch 9/100
# 217/217 [==============================] - 36s 168ms/step - loss: 0.2071 - val_loss: 0.4672
# Epoch 10/100
# 217/217 [==============================] - 36s 166ms/step - loss: 0.2079 - val_loss: 0.4703
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x7f803b03d950> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x7f803b03d950> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# [[0.7896251678466797, 323.21628189086914], [0.7056500315666199, 393.75567603111267], [0.034592948853969574, 322.0106189250946], [0.12147105485200882, 247.19731307029724], [0.06978099793195724, 485.439013004303], [0.7203347682952881, 491.68770813941956], [0.2789756655693054, 611.9784109592438], [0.25344130396842957, 360.93927478790283], [0.1510688066482544, 340.78828501701355], [0.17145203053951263, 360.37486004829407]]
# ['18174' '16507' '6210' '18872' '16509' '6641' '16511' '16510' '423' '422'] [1.         0.97042622 0.96664569 0.96377084 0.93248522 0.92076359
#  0.91201931 0.9086482  0.88704273 0.87982904]
# /Users/ishigurofutoshi/opt/anaconda3/envs/pems/lib/python3.7/site-packages/sklearn/impute/_iterative.py:701: ConvergenceWarning: [IterativeImputer] Early stopping criterion not reached.
#   ConvergenceWarning,
# Epoch 1/100
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_train_function.<locals>.train_function at 0x7f802c0983b0> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_train_function.<locals>.train_function at 0x7f802c0983b0> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# 216/217 [============================>.] - ETA: 0s - loss: 0.2282WARNING:tensorflow:AutoGraph could not transform <function Model.make_test_function.<locals>.test_function at 0x7f803b17e050> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_test_function.<locals>.test_function at 0x7f803b17e050> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# 217/217 [==============================] - 35s 156ms/step - loss: 0.2282 - val_loss: 0.4574
# Epoch 2/100
# ...
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x7f815c0beef0> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# [[0.7896251678466797, 323.21628189086914], [0.7056500315666199, 393.75567603111267], [0.034592948853969574, 322.0106189250946], [0.12147105485200882, 247.19731307029724], [0.06978099793195724, 485.439013004303], [0.7203347682952881, 491.68770813941956], [0.2789756655693054, 611.9784109592438], [0.25344130396842957, 360.93927478790283], [0.1510688066482544, 340.78828501701355], [0.17145203053951263, 360.37486004829407], [0.4433574974536896, 248.33663821220398], [0.17442436516284943, 211.6865108013153], [1.2589073181152344, 284.8358778953552], [0.1714579313993454, 539.7857820987701], [0.8553455471992493, 275.93814301490784], [0.41448527574539185, 375.74791717529297], [0.2700374722480774, 410.61057806015015], [0.8696132302284241, 512.0884847640991], [0.17489522695541382, 373.08255410194397], [0.14265559613704681, 239.7206311225891], [0.24942438304424286, 205.24901294708252], [0.07952670753002167, 476.9198019504547], [0.7886395454406738, 745.8308343887329], [0.17871837317943573, 309.0615658760071], [0.04711813107132912, 479.7683298587799], [0.16494913399219513, 272.6537227630615], [0.3915064334869385, 368.6084179878235]]
# ['18852' '6218' '6669' '6670' '471' '4651' '16510' '16511' '2135' '6712'] [1.         0.99674375 0.94931862 0.91266496 0.87008835 0.86674769
#  0.84084185 0.83821558 0.82968511 0.82334805]
# /Users/ishigurofutoshi/opt/anaconda3/envs/pems/lib/python3.7/site-packages/sklearn/impute/_iterative.py:701: ConvergenceWarning: [IterativeImputer] Early stopping criterion not reached.
#   ConvergenceWarning,
# Epoch 1/100
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_train_function.<locals>.train_function at 0x7f803b03df80> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_train_function.<locals>.train_function at 0x7f803b03df80> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# 216/217 [============================>.] - ETA: 0s - loss: 0.2466WARNING:tensorflow:AutoGraph could not transform <function Model.make_test_function.<locals>.test_function at 0x7f803b00b3b0> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_test_function.<locals>.test_function at 0x7f803b00b3b0> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# 217/217 [==============================] - 35s 155ms/step - loss: 0.2465 - val_loss: 0.6237
# Epoch 2/100
# 217/217 [==============================] - 34s 156ms/step - loss: 0.2372 - val_loss: 0.6222
# Epoch 3/100
# 217/217 [==============================] - 34s 156ms/step - loss: 0.2357 - val_loss: 0.6149
# Epoch 4/100
# 217/217 [==============================] - 34s 156ms/step - loss: 0.2338 - val_loss: 0.6059
# Epoch 5/100
# 217/217 [==============================] - 34s 157ms/step - loss: 0.2340 - val_loss: 0.6111
# Epoch 6/100
# 217/217 [==============================] - 34s 156ms/step - loss: 0.2324 - val_loss: 0.6142
# Epoch 7/100
# 217/217 [==============================] - 34s 157ms/step - loss: 0.2312 - val_loss: 0.6334
# Epoch 8/100
# 217/217 [==============================] - 34s 157ms/step - loss: 0.2298 - val_loss: 0.6071
# Epoch 9/100
# 217/217 [==============================] - 34s 158ms/step - loss: 0.2296 - val_loss: 0.6102
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x7f803aef5950> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x7f803aef5950> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# [[0.7896251678466797, 323.21628189086914], [0.7056500315666199, 393.75567603111267], [0.034592948853969574, 322.0106189250946], [0.12147105485200882, 247.19731307029724], [0.06978099793195724, 485.439013004303], [0.7203347682952881, 491.68770813941956], [0.2789756655693054, 611.9784109592438], [0.25344130396842957, 360.93927478790283], [0.1510688066482544, 340.78828501701355], [0.17145203053951263, 360.37486004829407], [0.4433574974536896, 248.33663821220398], [0.17442436516284943, 211.6865108013153], [1.2589073181152344, 284.8358778953552], [0.1714579313993454, 539.7857820987701], [0.8553455471992493, 275.93814301490784], [0.41448527574539185, 375.74791717529297], [0.2700374722480774, 410.61057806015015], [0.8696132302284241, 512.0884847640991], [0.17489522695541382, 373.08255410194397], [0.14265559613704681, 239.7206311225891], [0.24942438304424286, 205.24901294708252], [0.07952670753002167, 476.9198019504547], [0.7886395454406738, 745.8308343887329], [0.17871837317943573, 309.0615658760071], [0.04711813107132912, 479.7683298587799], [0.16494913399219513, 272.6537227630615], [0.3915064334869385, 368.6084179878235], [0.2847481071949005, 306.96273469924927]]
# ['18854' '6219' '6675' '6674' '16207' '13147' '6673' '6211' '6213' '274'] [1.         0.84735675 0.6592735  0.58699768 0.58262459 0.52738983
#  0.5242282  0.48194369 0.47649747 0.47525609]
# /Users/ishigurofutoshi/opt/anaconda3/envs/pems/lib/python3.7/site-packages/sklearn/impute/_iterative.py:701: ConvergenceWarning: [IterativeImputer] Early stopping criterion not reached.
#   ConvergenceWarning,
# Epoch 1/100
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_train_function.<locals>.train_function at 0x7f802bfdc4d0> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_train_function.<locals>.train_function at 0x7f802bfdc4d0> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# 216/217 [============================>.] - ETA: 0s - loss: 0.3875WARNING:tensorflow:AutoGraph could not transform <function Model.make_test_function.<locals>.test_function at 0x7f803aeb0c20> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_test_function.<locals>.test_function at 0x7f803aeb0c20> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# 217/217 [==============================] - 35s 155ms/step - loss: 0.3873 - val_loss: 0.6732
# Epoch 2/100
# 217/217 [==============================] - 34s 154ms/step - loss: 0.3706 - val_loss: 0.6509
# Epoch 3/100
# 217/217 [==============================] - 34s 155ms/step - loss: 0.3617 - val_loss: 0.6691
# Epoch 4/100
# 217/217 [==============================] - 34s 156ms/step - loss: 0.3541 - val_loss: 0.6422
# Epoch 5/100
# 217/217 [==============================] - 34s 157ms/step - loss: 0.3476 - val_loss: 0.6823
# Epoch 6/100
# 217/217 [==============================] - 34s 156ms/step - loss: 0.3417 - val_loss: 0.6802
# Epoch 7/100
# 217/217 [==============================] - 34s 156ms/step - loss: 0.3337 - val_loss: 0.7473
# Epoch 8/100
# 217/217 [==============================] - 34s 157ms/step - loss: 0.3288 - val_loss: 0.7164
# Epoch 9/100
# 217/217 [==============================] - 34s 157ms/step - loss: 0.3272 - val_loss: 0.6878
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x7f802c0365f0> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x7f802c0365f0> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# [[0.7896251678466797, 323.21628189086914], [0.7056500315666199, 393.75567603111267], [0.034592948853969574, 322.0106189250946], [0.12147105485200882, 247.19731307029724], [0.06978099793195724, 485.439013004303], [0.7203347682952881, 491.68770813941956], [0.2789756655693054, 611.9784109592438], [0.25344130396842957, 360.93927478790283], [0.1510688066482544, 340.78828501701355], [0.17145203053951263, 360.37486004829407], [0.4433574974536896, 248.33663821220398], [0.17442436516284943, 211.6865108013153], [1.2589073181152344, 284.8358778953552], [0.1714579313993454, 539.7857820987701], [0.8553455471992493, 275.93814301490784], [0.41448527574539185, 375.74791717529297], [0.2700374722480774, 410.61057806015015], [0.8696132302284241, 512.0884847640991], [0.17489522695541382, 373.08255410194397], [0.14265559613704681, 239.7206311225891], [0.24942438304424286, 205.24901294708252], [0.07952670753002167, 476.9198019504547], [0.7886395454406738, 745.8308343887329], [0.17871837317943573, 309.0615658760071], [0.04711813107132912, 479.7683298587799], [0.16494913399219513, 272.6537227630615], [0.3915064334869385, 368.6084179878235], [0.2847481071949005, 306.96273469924927], [2.1915714740753174, 305.8481101989746]]
# ['18856' '6204' '6619' '6620' '6622' '6700' '365' '379' '19839' '13867'] [1.         0.90479798 0.59823424 0.55046074 0.51770855 0.48456344
#  0.48315116 0.48035586 0.48011428 0.47989103]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /var/folders/ns/m6xqd78d419c4bs1hmdmhkh00000gp/T/ipykernel_82354/3328370063.py in <module>
#       5     #DataFrameの作成（欠損作成＆補完）
#       6
# ----> 7     inputs_df,labels_df,inputs_df_time,labels_df_time,select_features = init_df(target,imputation_select)
#       8
#       9     #単一値補完の描画
#
# /var/folders/ns/m6xqd78d419c4bs1hmdmhkh00000gp/T/ipykernel_82354/3614111752.py in init_df(target, imputation_select)
#      12         for route in select_features:
#      13             for i in inputs_df_time.loc[inputs_df_time["5 Minutes"].dt.hour==t].sample(frac=missing_rate).index:
# ---> 14                 inputs_df_time.loc[i,route] = np.nan
#      15
#      16     inputs_df = inputs_df_time.drop(["5 Minutes"],axis=1)
#
# ~/opt/anaconda3/envs/pems/lib/python3.7/site-packages/pandas/core/indexing.py in __setitem__(self, key, value)
#     721
#     722         iloc = self if self.name == "iloc" else self.obj.iloc
# --> 723         iloc._setitem_with_indexer(indexer, value, self.name)
#     724
#     725     def _validate_key(self, key, axis: int):
#
# ~/opt/anaconda3/envs/pems/lib/python3.7/site-packages/pandas/core/indexing.py in _setitem_with_indexer(self, indexer, value, name)
#    1728         if take_split_path:
#    1729             # We have to operate column-wise
# -> 1730             self._setitem_with_indexer_split_path(indexer, value, name)
#    1731         else:
#    1732             self._setitem_single_block(indexer, value, name)
#
# ~/opt/anaconda3/envs/pems/lib/python3.7/site-packages/pandas/core/indexing.py in _setitem_with_indexer_split_path(self, indexer, value, name)
#    1815             # scalar value
#    1816             for loc in ilocs:
# -> 1817                 self._setitem_single_column(loc, value, pi)
#    1818
#    1819     def _setitem_with_indexer_2d_value(self, indexer, value):
#
# ~/opt/anaconda3/envs/pems/lib/python3.7/site-packages/pandas/core/indexing.py in _setitem_single_column(self, loc, value, plane_indexer)
#    1922
#    1923         # reset the sliced object if unique
# -> 1924         self.obj._iset_item(loc, ser)
#    1925
#    1926     def _setitem_single_block(self, indexer, value, name: str):
#
# ~/opt/anaconda3/envs/pems/lib/python3.7/site-packages/pandas/core/frame.py in _iset_item(self, loc, value)
#    3763
#    3764     def _iset_item(self, loc: int, value) -> None:
# -> 3765         arraylike = self._sanitize_column(value)
#    3766         self._iset_item_mgr(loc, arraylike)
#    3767
#
# ~/opt/anaconda3/envs/pems/lib/python3.7/site-packages/pandas/core/frame.py in _sanitize_column(self, value)
#    4500         numpy.ndarray or ExtensionArray
#    4501         """
# -> 4502         self._ensure_valid_index(value)
#    4503
#    4504         # We should never get here with DataFrame value
#
# ~/opt/anaconda3/envs/pems/lib/python3.7/site-packages/pandas/core/frame.py in _ensure_valid_index(self, value)
#    3841         """
#    3842         # GH5632, make sure that we are a Series convertible
# -> 3843         if not len(self.index) and is_list_like(value) and len(value):
#    3844             if not isinstance(value, DataFrame):
#    3845                 try:
#
# ~/opt/anaconda3/envs/pems/lib/python3.7/site-packages/pandas/core/indexes/range.py in __len__(self)
#     808         return the length of the RangeIndex
#     809         """
# --> 810         return len(self._range)
#     811
#     812     @property
#
# KeyboardInterrupt:

# %%
evaluation_df = pd.DataFrame(evaluation_list,index=df.columns,columns=["RMSE","training_time"])

dirname = excel_output_path
os.makedirs(dirname, exist_ok=True)
evaluation_df.to_excel(excel_output_path+"/RMSE.xlsx")
